# %%
import pandas as pd
import numpy as np
import time
from pyspark.sql.functions import col, when, rand

# %% [markdown]
# # 실습 파일 준비하기

# %%
import gc

def generate_large_csv_in_chunks(file_path, chunk_size=1_000_000, total_rows=100_000_000):
    """
    DataFrame 없이 청크 단위로 대용량 CSV 파일을 DBFS에 직접 생성하는 함수
    
    매개변수:
    dbfs_path (str): 파일이 저장될 DBFS 경로
    chunk_size (int): 각 청크당 행 수
    total_rows (int): 생성할 총 행 수
    """
    
    # 카테고리 목록
    categories = ['A', 'B', 'C', 'D', 'E']
    
    # 시작 시간 기록
    start_time = time.time()
    
    # 파일 생성 및 헤더 작성
    with open(file_path, 'w') as f:
        f.write('category,value\n')
    
    # 청크 단위로 데이터 작성
    num_chunks = total_rows // chunk_size
    
    for i in range(num_chunks):
        chunk_start = time.time()
        print(f"청크 생성 중: {i+1}/{num_chunks}...")
        
        with open(file_path, 'a') as f:
            # 한 번에 작은 그룹으로 처리 (메모리 효율성)
            for j in range(0, chunk_size, 10000):
                rows_to_write = min(10000, chunk_size - j)
                
                # 카테고리 생성
                cat_indices = np.random.randint(0, len(categories), rows_to_write)
                # 값 생성
                values = np.random.rand(rows_to_write) * 100
                
                # 데이터를 직접 문자열로 변환하여 파일에 쓰기
                for k in range(rows_to_write):
                    f.write(f"{categories[cat_indices[k]]},{values[k]:.6f}\n")
                
                # 작은 청크 처리 후 메모리 정리
                del cat_indices, values
            
        chunk_end = time.time()
        print(f"청크 {i+1} 완료: {chunk_end - chunk_start:.2f}초 소요")
        gc.collect()  # 명시적 가비지 컬렉션
        
    total_time = time.time() - start_time
    print(f"파일 생성 완료: {file_path}")
    print(f"총 소요 시간: {total_time:.2f}초, 평균 초당 {total_rows/total_time:.2f}행 생성")

# %%
One_B_test = True

if One_B_test:
    # 10억개 짜리 파일 생성
    total_rows = 1_000_000_000
    file_name = 'large_data_1B.csv'
else:
    # 1억개 짜리 파일 생성
    total_rows = 100_000_000
    file_name = 'large_data_100M.csv'

file_path = f'/tmp/{file_name}'

# %%
generate_large_csv_in_chunks(file_path, chunk_size=1_000_000, total_rows=total_rows)
# Out:
# 청크 생성 중: 1/100...
# 청크 1 완료: 1.29초 소요
# 청크 생성 중: 2/100...
# 청크 2 완료: 1.06초 소요
# 청크 생성 중: 3/100...
# 청크 3 완료: 0.91초 소요
# 청크 생성 중: 4/100...
# 청크 4 완료: 0.92초 소요
# 청크 생성 중: 5/100...
# 청크 5 완료: 1.00초 소요
# 청크 생성 중: 6/100...
# 청크 6 완료: 1.32초 소요
# 청크 생성 중: 7/100...
# 청크 7 완료: 0.92초 소요
# 청크 생성 중: 8/100...
# 청크 8 완료: 0.93초 소요
# 청크 생성 중: 9/100...
# 청크 9 완료: 0.92초 소요
# 청크 생성 중: 10/100...
# 청크 10 완료: 0.93초 소요
# 청크 생성 중: 11/100...
# 청크 11 완료: 0.91초 소요
# 청크 생성 중: 12/100...
# 청크 12 완료: 0.91초 소요
# 청크 생성 중: 13/100...
# 청크 13 완료: 1.04초 소요
# 청크 생성 중: 14/100...
# 청크 14 완료: 0.90초 소요
# 청크 생성 중: 15/100...
# 청크 15 완료: 0.93초 소요
# 청크 생성 중: 16/100...
# 청크 16 완료: 0.91초 소요
# 청크 생성 중: 17/100...
# 청크 17 완료: 0.92초 소요
# 청크 생성 중: 18/100...
# 청크 18 완료: 0.92초 소요
# 청크 생성 중: 19/100...
# 청크 19 완료: 0.97초 소요
# 청크 생성 중: 20/100...
# 청크 20 완료: 0.90초 소요
# 청크 생성 중: 21/100...
# 청크 21 완료: 0.93초 소요
# 청크 생성 중: 22/100...
# 청크 22 완료: 0.93초 소요
# 청크 생성 중: 23/100...
# 청크 23 완료: 0.95초 소요
# 청크 생성 중: 24/100...
# 청크 24 완료: 0.93초 소요
# 청크 생성 중: 25/100...
# 청크 25 완료: 0.93초 소요
# 청크 생성 중: 26/100...
# 청크 26 완료: 0.91초 소요
# 청크 생성 중: 27/100...
# 청크 27 완료: 0.93초 소요
# 청크 생성 중: 28/100...
# 청크 28 완료: 0.91초 소요
# 청크 생성 중: 29/100...
# 청크 29 완료: 0.94초 소요
# 청크 생성 중: 30/100...
# 청크 30 완료: 0.89초 소요
# 청크 생성 중: 31/100...
# 청크 31 완료: 1.04초 소요
# 청크 생성 중: 32/100...
# 청크 32 완료: 0.90초 소요
# 청크 생성 중: 33/100...
# 청크 33 완료: 0.90초 소요
# 청크 생성 중: 34/100...
# 청크 34 완료: 0.96초 소요
# 청크 생성 중: 35/100...
# 청크 35 완료: 0.89초 소요
# 청크 생성 중: 36/100...
# 청크 36 완료: 1.00초 소요
# 청크 생성 중: 37/100...
# 청크 37 완료: 0.90초 소요
# 청크 생성 중: 38/100...
# 청크 38 완료: 0.92초 소요
# 청크 생성 중: 39/100...
# 청크 39 완료: 0.90초 소요
# 청크 생성 중: 40/100...
# 청크 40 완료: 1.08초 소요
# 청크 생성 중: 41/100...
# 청크 41 완료: 0.92초 소요
# 청크 생성 중: 42/100...
# 청크 42 완료: 0.92초 소요
# 청크 생성 중: 43/100...
# 청크 43 완료: 0.94초 소요
# 청크 생성 중: 44/100...
# 청크 44 완료: 1.13초 소요
# 청크 생성 중: 45/100...
# 청크 45 완료: 0.91초 소요
# 청크 생성 중: 46/100...
# 청크 46 완료: 0.92초 소요
# 청크 생성 중: 47/100...
# 청크 47 완료: 0.90초 소요
# 청크 생성 중: 48/100...
# 청크 48 완료: 0.94초 소요
# 청크 생성 중: 49/100...
# 청크 49 완료: 0.91초 소요
# 청크 생성 중: 50/100...
# 청크 50 완료: 0.90초 소요
# 청크 생성 중: 51/100...
# 청크 51 완료: 0.95초 소요
# 청크 생성 중: 52/100...
# 청크 52 완료: 0.90초 소요
# 청크 생성 중: 53/100...
# 청크 53 완료: 0.93초 소요
# 청크 생성 중: 54/100...
# 청크 54 완료: 0.91초 소요
# 청크 생성 중: 55/100...
# 청크 55 완료: 0.92초 소요
# 청크 생성 중: 56/100...
# 청크 56 완료: 0.89초 소요
# 청크 생성 중: 57/100...
# 청크 57 완료: 0.90초 소요
# 청크 생성 중: 58/100...
# 청크 58 완료: 0.92초 소요
# 청크 생성 중: 59/100...
# 청크 59 완료: 1.12초 소요
# 청크 생성 중: 60/100...
# 청크 60 완료: 0.94초 소요
# 청크 생성 중: 61/100...
# 청크 61 완료: 0.93초 소요
# 청크 생성 중: 62/100...
# 청크 62 완료: 0.92초 소요
# 청크 생성 중: 63/100...
# 청크 63 완료: 0.94초 소요
# 청크 생성 중: 64/100...
# 청크 64 완료: 1.13초 소요
# 청크 생성 중: 65/100...
# 청크 65 완료: 0.91초 소요
# 청크 생성 중: 66/100...
# 청크 66 완료: 0.90초 소요
# 청크 생성 중: 67/100...
# 청크 67 완료: 0.91초 소요
# 청크 생성 중: 68/100...
# 청크 68 완료: 0.92초 소요
# 청크 생성 중: 69/100...
# 청크 69 완료: 0.96초 소요
# 청크 생성 중: 70/100...
# 청크 70 완료: 0.92초 소요
# 청크 생성 중: 71/100...
# 청크 71 완료: 0.91초 소요
# 청크 생성 중: 72/100...
# 청크 72 완료: 0.97초 소요
# 청크 생성 중: 73/100...
# 청크 73 완료: 0.91초 소요
# 청크 생성 중: 74/100...
# 청크 74 완료: 0.93초 소요
# 청크 생성 중: 75/100...
# 청크 75 완료: 0.89초 소요
# 청크 생성 중: 76/100...
# 청크 76 완료: 0.90초 소요
# 청크 생성 중: 77/100...
# 청크 77 완료: 0.91초 소요
# 청크 생성 중: 78/100...
# 청크 78 완료: 0.91초 소요
# 청크 생성 중: 79/100...
# 청크 79 완료: 1.36초 소요
# 청크 생성 중: 80/100...
# 청크 80 완료: 1.05초 소요
# 청크 생성 중: 81/100...
# 청크 81 완료: 0.93초 소요
# 청크 생성 중: 82/100...
# 청크 82 완료: 0.93초 소요
# 청크 생성 중: 83/100...
# 청크 83 완료: 0.97초 소요
# 청크 생성 중: 84/100...
# 청크 84 완료: 0.91초 소요
# 청크 생성 중: 85/100...
# 청크 85 완료: 0.94초 소요
# 청크 생성 중: 86/100...
# 청크 86 완료: 0.89초 소요
# 청크 생성 중: 87/100...
# 청크 87 완료: 0.90초 소요
# 청크 생성 중: 88/100...
# 청크 88 완료: 0.92초 소요
# 청크 생성 중: 89/100...
# 청크 89 완료: 0.90초 소요
# 청크 생성 중: 90/100...
# 청크 90 완료: 0.95초 소요
# 청크 생성 중: 91/100...
# 청크 91 완료: 0.94초 소요
# 청크 생성 중: 92/100...
# 청크 92 완료: 0.97초 소요
# 청크 생성 중: 93/100...
# 청크 93 완료: 0.90초 소요
# 청크 생성 중: 94/100...
# 청크 94 완료: 0.93초 소요
# 청크 생성 중: 95/100...
# 청크 95 완료: 0.89초 소요
# 청크 생성 중: 96/100...
# 청크 96 완료: 0.94초 소요
# 청크 생성 중: 97/100...
# 청크 97 완료: 0.91초 소요
# 청크 생성 중: 98/100...
# 청크 98 완료: 0.96초 소요
# 청크 생성 중: 99/100...
# 청크 99 완료: 0.98초 소요
# 청크 생성 중: 100/100...
# 청크 100 완료: 0.94초 소요
# 파일 생성 완료: /tmp/large_data_100M.csv
# 총 소요 시간: 107.27초, 평균 초당 932265.64행 생성

# %%
# %sh

ls -tl /tmp/*.csv
# Out:
# -rw-r--r-- 1 root root 11899997845 Mar 24 06:05 /tmp/large_data_1B.csv
# -rw-r--r-- 1 root root  1190002162 Mar 24 05:42 /tmp/large_data_100M.csv

# %%
dbutils.fs.cp(f"file:{file_path}", f"dbfs:/{file_name}")
# Out:
# True

# %%
# 파일 확인 및 크기 체크
display(dbutils.fs.ls("dbfs:/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/car_sales_data.csv</td><td>car_sales_data.csv</td><td>45379</td><td>1742618060000</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/large_data_100M.csv</td><td>large_data_100M.csv</td><td>1190002162</td><td>1742795067000</td></tr><tr><td>dbfs:/large_data_1B.csv</td><td>large_data_1B.csv</td><td>11899997845</td><td>1742768984000</td></tr><tr><td>dbfs:/monthly_sales_by_brand/</td><td>monthly_sales_by_brand/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/car_sales_data.csv</td><td>car_sales_data.csv</td><td>45379</td><td>1742618060000</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/large_data_100M.csv</td><td>large_data_100M.csv</td><td>1190002162</td><td>1742795067000</td></tr><tr><td>dbfs:/large_data_1B.csv</td><td>large_data_1B.csv</td><td>11899997845</td><td>1742768984000</td></tr><tr><td>dbfs:/monthly_sales_by_brand/</td><td>monthly_sales_by_brand/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# # Spark으로 처리해보기

# %%
# 실행 모드 (deploy mode) 확인
print("Deploy mode:", spark.conf.get("spark.submit.deployMode", "Not Set"))
# Out:
# Deploy mode: Not Set

# %%
# lazy execution이 기본
# show, display, count, collect, write과 같은 action이 실행되어야 실제 코드들이 실행됨.
# - Action의 반대는 transformation (filter, groupBy, select)
df = spark.read.option("header", "true") \
               .csv(f"dbfs:/{file_name}")

# %%
# 하지만 inferSchema를 true로 주면 lazy execution이 무시되고 바로 실행됨
# - 원래는 샘플링을 해야하는데 Databricks Community Edition의 로컬 모드는 모든 것을 읽는 걸로 보임 
df = spark.read.option("header", "true") \
               .option("inferSchema", "true") \
               .csv(f"dbfs:/{file_name}")

# %%
display(df)  # action으로 간주됨
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category</th><th>value</th></tr></thead><tbody><tr><td>B</td><td>25.394258</td></tr><tr><td>E</td><td>86.717396</td></tr><tr><td>C</td><td>64.641403</td></tr><tr><td>B</td><td>21.997705</td></tr><tr><td>B</td><td>77.811007</td></tr><tr><td>B</td><td>18.464706</td></tr><tr><td>E</td><td>27.865266</td></tr><tr><td>D</td><td>38.638753</td></tr><tr><td>A</td><td>42.36043</td></tr><tr><td>D</td><td>23.679677</td></tr><tr><td>E</td><td>85.081051</td></tr><tr><td>D</td><td>22.804416</td></tr><tr><td>A</td><td>65.540665</td></tr><tr><td>E</td><td>48.79546</td></tr><tr><td>B</td><td>23.934039</td></tr><tr><td>A</td><td>99.267804</td></tr><tr><td>B</td><td>58.413235</td></tr><tr><td>B</td><td>48.538351</td></tr><tr><td>A</td><td>28.683904</td></tr><tr><td>A</td><td>26.546369</td></tr><tr><td>C</td><td>39.299227</td></tr><tr><td>E</td><td>5.961913</td></tr><tr><td>E</td><td>80.707435</td></tr><tr><td>A</td><td>50.642577</td></tr><tr><td>B</td><td>57.973136</td></tr><tr><td>A</td><td>68.533701</td></tr><tr><td>D</td><td>3.349551</td></tr><tr><td>E</td><td>23.017752</td></tr><tr><td>A</td><td>28.226322</td></tr><tr><td>A</td><td>27.020697</td></tr><tr><td>D</td><td>18.53388</td></tr><tr><td>D</td><td>15.296746</td></tr><tr><td>D</td><td>84.689155</td></tr><tr><td>C</td><td>81.167418</td></tr><tr><td>C</td><td>16.59472</td></tr><tr><td>C</td><td>80.601011</td></tr><tr><td>C</td><td>41.75618</td></tr><tr><td>A</td><td>27.35703</td></tr><tr><td>D</td><td>89.51018</td></tr><tr><td>B</td><td>56.891261</td></tr><tr><td>A</td><td>40.246922</td></tr><tr><td>A</td><td>41.02414</td></tr><tr><td>B</td><td>45.454147</td></tr><tr><td>A</td><td>14.217331</td></tr><tr><td>C</td><td>3.835833</td></tr><tr><td>E</td><td>95.58933</td></tr><tr><td>A</td><td>62.836938</td></tr><tr><td>E</td><td>60.054561</td></tr><tr><td>C</td><td>95.792339</td></tr><tr><td>A</td><td>56.717804</td></tr><tr><td>D</td><td>94.725486</td></tr><tr><td>C</td><td>50.714935</td></tr><tr><td>A</td><td>57.751459</td></tr><tr><td>E</td><td>96.746552</td></tr><tr><td>A</td><td>39.865555</td></tr><tr><td>B</td><td>99.189505</td></tr><tr><td>A</td><td>15.354091</td></tr><tr><td>C</td><td>26.486154</td></tr><tr><td>B</td><td>29.020353</td></tr><tr><td>A</td><td>16.418643</td></tr><tr><td>B</td><td>93.041205</td></tr><tr><td>B</td><td>89.907773</td></tr><tr><td>B</td><td>33.239803</td></tr><tr><td>D</td><td>43.611305</td></tr><tr><td>B</td><td>49.846027</td></tr><tr><td>E</td><td>61.897275</td></tr><tr><td>E</td><td>34.536968</td></tr><tr><td>D</td><td>92.177127</td></tr><tr><td>B</td><td>35.747754</td></tr><tr><td>D</td><td>35.043177</td></tr><tr><td>A</td><td>47.281227</td></tr><tr><td>D</td><td>64.839494</td></tr><tr><td>B</td><td>87.803291</td></tr><tr><td>E</td><td>7.794814</td></tr><tr><td>B</td><td>95.682459</td></tr><tr><td>E</td><td>16.325598</td></tr><tr><td>B</td><td>32.116525</td></tr><tr><td>B</td><td>17.848189</td></tr><tr><td>D</td><td>2.983304</td></tr><tr><td>D</td><td>94.147641</td></tr><tr><td>D</td><td>98.768374</td></tr><tr><td>B</td><td>69.396961</td></tr><tr><td>C</td><td>13.555633</td></tr><tr><td>A</td><td>38.55012</td></tr><tr><td>B</td><td>23.1842</td></tr><tr><td>B</td><td>56.993061</td></tr><tr><td>E</td><td>37.292834</td></tr><tr><td>A</td><td>27.196235</td></tr><tr><td>E</td><td>74.696111</td></tr><tr><td>E</td><td>95.801768</td></tr><tr><td>E</td><td>39.896816</td></tr><tr><td>A</td><td>50.22696</td></tr><tr><td>E</td><td>92.460734</td></tr><tr><td>C</td><td>64.373057</td></tr><tr><td>D</td><td>73.15348</td></tr><tr><td>B</td><td>30.027212</td></tr><tr><td>B</td><td>44.29275</td></tr><tr><td>C</td><td>35.674271</td></tr><tr><td>D</td><td>72.623808</td></tr><tr><td>B</td><td>23.518662</td></tr><tr><td>B</td><td>48.596721</td></tr><tr><td>B</td><td>1.691201</td></tr><tr><td>D</td><td>55.499115</td></tr><tr><td>A</td><td>0.581709</td></tr><tr><td> ...

# %%
num_partitions = df.rdd.getNumPartitions()
print("Number of partitions:", num_partitions)
# Out:
# Number of partitions: 89

# %%
record_count = df.count()
print("Number of records:", record_count)
# Out:
# Number of records: 1000000000

# %%
from pyspark.sql.functions import avg

# 벤치마크: 카테고리별 평균 계산
print("\n카테고리별 평균 계산:")

spark_start = time.time()
spark_result = df.groupby('category').agg(avg('value').alias('value_avg')).orderBy('category')
spark_result_collected = spark_result.collect()  # 액션 실행
spark_time = time.time() - spark_start
print(f"Spark 실행 시간: {spark_time:.2f}초")
print(spark_result_collected)
# Out:
# 카테고리별 평균 계산:
# Spark 실행 시간: 886.97초
# [Row(category='A', value_avg=50.00028650266013), Row(category='B', value_avg=50.00206989217908), Row(category='C', value_avg=50.00158353411273), Row(category='D', value_avg=50.00117236714155), Row(category='E', value_avg=50.00116377910072)]

# %% [markdown]
# # Pandas로 처리해보기

# %%
pandas_df = pd.read_csv(file_path)
pandas_df.head()
# Out:
# ---------------------------------------------------------------------------
# The Python process exited with exit code 137 (SIGKILL: Killed). This may have been caused by an OOM error. Check your command's memory usage.
#
#
#
# The last 10 KB of the process's stderr and stdout can be found below. See driver logs for full logs.
# ---------------------------------------------------------------------------
# Last messages on stderr:
# Mon Mar 24 05:33:54 2025 Connection to spark from PID  954
# Mon Mar 24 05:33:54 2025 Initialized gateway on port 45569
# Mon Mar 24 05:33:55 2025 Connected to spark.
# ---------------------------------------------------------------------------
# Last messages on stdout:
# NOTE: When using the `ipython kernel` entry point, Ctrl-C will not work.
#
# To exit, you will have to explicitly quit this process, by either sending
# "quit" from a client, or using Ctrl-\ in UNIX-like environments.
#
# To read more about this, see https://github.com/ipython/ipython/issues/2049
#
#
# To connect another client to this kernel, use:
#     --existing /databricks/kernel-connections/e765997198abec115992c75ba175295d1bcd97a8ed183b95a2746952d3d9ca7c.json
# 청크 생성 중: 1/100...
# 청크 1 완료: 1.29초 소요
# 청크 생성 중: 2/100...
# 청크 2 완료: 1.06초 소요
# 청크 생성 중: 3/100...
# 청크 3 완료: 0.91초 소요
# 청크 생성 중: 4/100...
# 청크 4 완료: 0.92초 소요
# 청크 생성 중: 5/100...
# 청크 5 완료: 1.00초 소요
# 청크 생성 중: 6/100...
# 청크 6 완료: 1.32초 소요
# 청크 생성 중: 7/100...
# 청크 7 완료: 0.92초 소요
# 청크 생성 중: 8/100...
# 청크 8 완료: 0.93초 소요
# 청크 생성 중: 9/100...
# 청크 9 완료: 0.92초 소요
# 청크 생성 중: 10/100...
# 청크 10 완료: 0.93초 소요
# 청크 생성 중: 11/100...
# 청크 11 완료: 0.91초 소요
# 청크 생성 중: 12/100...
# 청크 12 완료: 0.91초 소요
# 청크 생성 중: 13/100...
# 청크 13 완료: 1.04초 소요
# 청크 생성 중: 14/100...
# 청크 14 완료: 0.90초 소요
# 청크 생성 중: 15/100...
# 청크 15 완료: 0.93초 소요
# 청크 생성 중: 16/100...
# 청크 16 완료: 0.91초 소요
# 청크 생성 중: 17/100...
# 청크 17 완료: 0.92초 소요
# 청크 생성 중: 18/100...
# 청크 18 완료: 0.92초 소요
# 청크 생성 중: 19/100...
# 청크 19 완료: 0.97초 소요
# 청크 생성 중: 20/100...
# 청크 20 완료: 0.90초 소요
# 청크 생성 중: 21/100...
# 청크 21 완료: 0.93초 소요
# 청크 생성 중: 22/100...
# 청크 22 완료: 0.93초 소요
# 청크 생성 중: 23/100...
# 청크 23 완료: 0.95초 소요
# 청크 생성 중: 24/100...
# 청크 24 완료: 0.93초 소요
# 청크 생성 중: 25/100...
# 청크 25 완료: 0.93초 소요
# 청크 생성 중: 26/100...
# 청크 26 완료: 0.91초 소요
# 청크 생성 중: 27/100...
# 청크 27 완료: 0.93초 소요
# 청크 생성 중: 28/100...
# 청크 28 완료: 0.91초 소요
# 청크 생성 중: 29/100...
# 청크 29 완료: 0.94초 소요
# 청크 생성 중: 30/100...
# 청크 30 완료: 0.89초 소요
# 청크 생성 중: 31/100...
# 청크 31 완료: 1.04초 소요
# 청크 생성 중: 32/100...
# 청크 32 완료: 0.90초 소요
# 청크 생성 중: 33/100...
# 청크 33 완료: 0.90초 소요
# 청크 생성 중: 34/100...
# 청크 34 완료: 0.96초 소요
# 청크 생성 중: 35/100...
# 청크 35 완료: 0.89초 소요
# 청크 생성 중: 36/100...
# 청크 36 완료: 1.00초 소요
# 청크 생성 중: 37/100...
# 청크 37 완료: 0.90초 소요
# 청크 생성 중: 38/100...
# 청크 38 완료: 0.92초 소요
# 청크 생성 중: 39/100...
# 청크 39 완료: 0.90초 소요
# 청크 생성 중: 40/100...
# 청크 40 완료: 1.08초 소요
# 청크 생성 중: 41/100...
# 청크 41 완료: 0.92초 소요
# 청크 생성 중: 42/100...
# 청크 42 완료: 0.92초 소요
# 청크 생성 중: 43/100...
# 청크 43 완료: 0.94초 소요
# 청크 생성 중: 44/100...
# 청크 44 완료: 1.13초 소요
# 청크 생성 중: 45/100...
# 청크 45 완료: 0.91초 소요
# 청크 생성 중: 46/100...
# 청크 46 완료: 0.92초 소요
# 청크 생성 중: 47/100...
# 청크 47 완료: 0.90초 소요
# 청크 생성 중: 48/100...
# 청크 48 완료: 0.94초 소요
# 청크 생성 중: 49/100...
# 청크 49 완료: 0.91초 소요
# 청크 생성 중: 50/100...
# 청크 50 완료: 0.90초 소요
# 청크 생성 중: 51/100...
# 청크 51 완료: 0.95초 소요
# 청크 생성 중: 52/100...
# 청크 52 완료: 0.90초 소요
# 청크 생성 중: 53/100...
# 청크 53 완료: 0.93초 소요
# 청크 생성 중: 54/100...
# 청크 54 완료: 0.91초 소요
# 청크 생성 중: 55/100...
# 청크 55 완료: 0.92초 소요
# 청크 생성 중: 56/100...
# 청크 56 완료: 0.89초 소요
# 청크 생성 중: 57/100...
# 청크 57 완료: 0.90초 소요
# 청크 생성 중: 58/100...
# 청크 58 완료: 0.92초 소요
# 청크 생성 중: 59/100...
# 청크 59 완료: 1.12초 소요
# 청크 생성 중: 60/100...
# 청크 60 완료: 0.94초 소요
# 청크 생성 중: 61/100...
# 청크 61 완료: 0.93초 소요
# 청크 생성 중: 62/100...
# 청크 62 완료: 0.92초 소요
# 청크 생성 중: 63/100...
# 청크 63 완료: 0.94초 소요
# 청크 생성 중: 64/100...
# 청크 64 완료: 1.13초 소요
# 청크 생성 중: 65/100...
# 청크 65 완료: 0.91초 소요
# 청크 생성 중: 66/100...
# 청크 66 완료: 0.90초 소요
# 청크 생성 중: 67/100...
# 청크 67 완료: 0.91초 소요
# 청크 생성 중: 68/100...
# 청크 68 완료: 0.92초 소요
# 청크 생성 중: 69/100...
# 청크 69 완료: 0.96초 소요
# 청크 생성 중: 70/100...
# 청크 70 완료: 0.92초 소요
# 청크 생성 중: 71/100...
# 청크 71 완료: 0.91초 소요
# 청크 생성 중: 72/100...
# 청크 72 완료: 0.97초 소요
# 청크 생성 중: 73/100...
# 청크 73 완료: 0.91초 소요
# 청크 생성 중: 74/100...
# 청크 74 완료: 0.93초 소요
# 청크 생성 중: 75/100...
# 청크 75 완료: 0.89초 소요
# 청크 생성 중: 76/100...
# 청크 76 완료: 0.90초 소요
# 청크 생성 중: 77/100...
# 청크 77 완료: 0.91초 소요
# 청크 생성 중: 78/100...
# 청크 78 완료: 0.91초 소요
# 청크 생성 중: 79/100...
# 청크 79 완료: 1.36초 소요
# 청크 생성 중: 80/100...
# 청크 80 완료: 1.05초 소요
# 청크 생성 중: 81/100...
# 청크 81 완료: 0.93초 소요
# 청크 생성 중: 82/100...
# 청크 82 완료: 0.93초 소요
# 청크 생성 중: 83/100...
# 청크 83 완료: 0.97초 소요
# 청크 생성 중: 84/100...
# 청크 84 완료: 0.91초 소요
# 청크 생성 중: 85/100...
# 청크 85 완료: 0.94초 소요
# 청크 생성 중: 86/100...
# 청크 86 완료: 0.89초 소요
# 청크 생성 중: 87/100...
# 청크 87 완료: 0.90초 소요
# 청크 생성 중: 88/100...
# 청크 88 완료: 0.92초 소요
# 청크 생성 중: 89/100...
# 청크 89 완료: 0.90초 소요
# 청크 생성 중: 90/100...
# 청크 90 완료: 0.95초 소요
# 청크 생성 중: 91/100...
# 청크 91 완료: 0.94초 소요
# 청크 생성 중: 92/100...
# 청크 92 완료: 0.97초 소요
# 청크 생성 중: 93/100...
# 청크 93 완료: 0.90초 소요
# 청크 생성 중: 94/100...
# 청크 94 완료: 0.93초 소요
# 청크 생성 중: 95/100...
# 청크 95 완료: 0.89초 소요
# 청크 생성 중: 96/100...
# 청크 96 완료: 0.94초 소요
# 청크 생성 중: 97/100...
# 청크 97 완료: 0.91초 소요
# 청크 생성 중: 98/100...
# 청크 98 완료: 0.96초 소요
# 청크 생성 중: 99/100...
# 청크 99 완료: 0.98초 소요
# 청크 생성 중: 100/100...
# 청크 100 완료: 0.94초 소요
# 파일 생성 완료: /tmp/large_data_100M.csv
# 총 소요 시간: 107.27초, 평균 초당 932265.64행 생성
# -rw-r--r-- 1 root root 1190002162 Mar 24 05:42 /tmp/large_data_100M.csv
# Deploy mode: Not Set
# Number of partitions: 9
# Number of records: 100000000
#
# 카테고리별 평균 계산:
# Spark 실행 시간: 96.61초
# [Row(category='A', value_avg=50.007881583833516), Row(category='B', value_avg=49.99531509053571), Row(category='C', value_avg=50.01214486788624), Row(category='D', value_avg=50.00789971119179), Row(category='E', value_avg=49.99406885572276)]
#
# 카테고리별 평균 계산:
# Pandas Execution Time: 7.46 seconds
#   category      value
# 0        A  50.007882
# 1        B  49.995315
# 2        C  50.012145
# 3        D  50.007900
# 4        E  49.994069
# -rw-r--r-- 1 root root 11899997845 Mar 24 06:05 /tmp/large_data_1B.csv
# -rw-r--r-- 1 root root  1190002162 Mar 24 05:42 /tmp/large_data_100M.csv
# Deploy mode: Not Set
# Number of partitions: 89
# Number of records: 1000000000
#
# 카테고리별 평균 계산:
# Spark 실행 시간: 886.97초
# [Row(category='A', value_avg=50.00028650266013), Row(category='B', value_avg=50.00206989217908), Row(category='C', value_avg=50.00158353411273), Row(category='D', value_avg=50.00117236714155), Row(category='E', value_avg=50.00116377910072)]

# %%
# 벤치마크: 카테고리별 평균 계산
print("\n카테고리별 평균 계산:")

start_pandas = time.time()    
# pandas_counts = pandas_df['category'].value_counts().sort_index()
pandas_counts = pandas_df.groupby('category', as_index=False)['value'].mean().sort_values('category')
end_pandas = time.time()    
print(f"Pandas Execution Time: {end_pandas - start_pandas:.2f} seconds")

print(pandas_counts.head())
# Out:
# 카테고리별 평균 계산:
# Pandas Execution Time: 7.46 seconds
#   category      value
# 0        A  50.007882
# 1        B  49.995315
# 2        C  50.012145
# 3        D  50.007900
# 4        E  49.994069
